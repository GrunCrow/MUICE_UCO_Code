# %% [markdown]
# <a href="https://colab.research.google.com/github/ayrna/ap2122/blob/main/redes_recurrentes/time_series_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aprendizaje Profundo - Práctica 2: Redes Neuronales Recurrentes
#
# A continuación se va a realizar el ejercicio propuesto en clase haciendo uso de redes neuronales recurrentes.
#
# Utilizaremos una serie temporal sobre producción industrial de los servicios públicos de electricidad y gas en Estados Unidos, de los años 1939 a 2019, con frecuencia de muestreo mensual.
#
# Se repetirá el entrenamiento de la red cambiando los parámetros del modelo. Se modificará el tamaño de batch (que se estableció a 500) y el número de neuronas de la LSTM o de la GRU (que se estableció a 32). También se probará a incrementar el número de épocas.

# %% [markdown]
# En este cuaderno, vamos a usar keras para construir una red LSTM que resuelva un problema de predicción en series temporales.

# %%
import tensorflow as tf
from tensorflow import keras

import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# El siguiente paso es cargar nuestro conjunto de datos de entrenamiento como un `DataFrame` de Pandas. A continuación, podemos extraer la matriz `numpy` del `DataFrame` y convertir los valores enteros en valores de punto flotante, que son más adecuados para el modelado con una red neuronal.

# %%
# Cargar el conjunto de datos usando pandas
df = pd.read_csv("data/produccion-energia.csv")

# Rename columns - DATE,IPG2211A2N
df.columns = ['date', 'ipg']

# Dar el formato correcto a la fecha y usarlo como índice
df.Month = pd.to_datetime(df.date)
df.set_index('date', inplace=True)

# Mostrar los primeros datos
print(df.head())

# Usar matplotlib para mostrar la serie
df.plot()
plt.title("Producción Industrial de gas y electricidad desde 1939 a 2019")
plt.ylabel("Producción Industrial")
plt.show()

# Fijar la semilla para reproducibilidad
numpy.random.seed(7)
# Out:
#                ipg
# date
# 1939-01-01  3.3842
# 1939-02-01  3.4100
# 1939-03-01  3.4875
# 1939-04-01  3.5133
# 1939-05-01  3.5133
# <ipython-input-9-aa6c29b708c1>:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.Month = pd.to_datetime(df.date)

# %% [markdown]
# Las redes LSTM pueden ser sensibles a la escala de los datos de entrada. Puede ser buena idea rescalar los datos en el rango [0,1]. Para ello, vamos a usar `MinMaxScaler`.

# %%
ipg = df['ipg']
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(ipg.values.reshape(-1,1))

# %% [markdown]
# Después de modelar nuestros datos y estimar su rendimiento en el conjunto de datos de entrenamiento, tenemos que hacernos una idea de su comportamiento con datos no vistos. Con los datos de series temporales, la secuencia de valores es importante. Un método sencillo que podemos utilizar es dividir el conjunto de datos ordenados en conjuntos de datos de entrenamiento y otro de test. El código siguiente calcula el índice del punto de división y separa los datos en conjuntos de datos de entrenamiento con el 67% de las observaciones que podemos utilizar para entrenar nuestro modelo, dejando el 33% restante para probar el modelo.

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# Ahora vamos a definir una función que va a generar los datos para el entrenamiento de la LSTM.
#
# La función toma dos argumentos: el conjunto de datos, que es un array de NumPy que queremos convertir en un conjunto de datos, y el look_back, que es el número de pasos de tiempo anteriores que se utilizarán como variables de entrada para predecir el siguiente período de tiempo - en este caso, por defecto, 1.
#
# Este valor predeterminado creará un conjunto de datos donde X es el número de pasajeros en un momento dado (t) e Y es el número de pasajeros en el siguiente momento (t + 1).
#
# De esta forma, estamos siguiendo la estrategia `one-to-one`.

# %%
# Convertir un array en un conjunto de datos
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %% [markdown]
# Ahora podemos utilizar esta función para preparar los conjuntos de datos de entrenamiento y test para el modelado.

# %%
look_back = 1
# Preparar el conjunto de train
trainX, trainY = create_dataset(train, look_back)

# Preparar el conjunto de test
testX, testY = create_dataset(test, look_back)

# %% [markdown]
# Podríamos haber hecho esto de forma más fácil usando el método `shift()`.

# %% [markdown]
# La red LSTM espera que los datos de entrada (X) tenga una estructura 3D de la siguiente forma: `[samples, time steps, features]`. Los `samples` son el número de instantes (filas) que vamos a usar para entrenar. En `time_steps` tendremos tantos como entradas reciba a la vez la red por cada instante de tiempo. En `features` vamos a tener las distintas variables que pudiera considerar la red.
#
# En nuestro caso, el array es de `[samples, features]`, nos falta una dimensión. Además, `time_steps=1` (`one-to-one`) y `features=1` (univariante). Pero tenemos que convertir la X a 3D. Lo haremos usando `reshape()`.

# %%
# Reshape para tener [samples, time steps, features]
trainX = trainX.reshape(trainX.shape[0],1,trainX.shape[1])
testX = testX.reshape(testX.shape[0],1,testX.shape[1])

# %% [markdown]
# Ahora ya podemos diseñar nuestra red LSTM para el problema de predicción.
#
# Vamos a tener una capa visible con 1 entrada, una capa oculta con 4 bloques LSTM y una capa de salida que realizará una predicción. La función de activación sigmoide se va a usar para los bloques LSTM.
#
# La opción `stateful=True` es importante. Hace que la memoria de la LSTM no se resetee después de cada batch. Obliga a especificar el `batch_size`, ya que así sabremos la memoria máxima.

# %%
# Tamaño de batch
batch_size=1

# Crear un modelo secuencial
model = Sequential()

# Crear una capa LSTM
model.add(LSTM(10, batch_input_shape=(batch_size, look_back, 1), stateful=True))

# Crear una capa densa
model.add(Dense(1))

# %% [markdown]
# Ahora compilamos y entrenamos durante 100 épocas con tamaño de batch 1.
#
# Para forzar a que el estado se resetee una vez hayamos pasado por toda la serie temporal, vamos a incluir un bucle para el número de épocas, en lugar de usar la forma habitual.

# %%
# Compilar el modelo
model.compile(optimizer="adam", loss='mean_squared_error')

# Entrenamiento habitual (no resetearía el estado)
# model.fit(trainX, trainY, epochs=30, batch_size=1)

# Entrenar el modelo con reseteo explícito
for i in range(100):
  print('Época %d'%(i))
  model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
  model.reset_states()
# Out:
# Época 0
# 645/645 - 2s - loss: 8.0169e-04 - 2s/epoch - 4ms/step
# Época 1
# 645/645 - 1s - loss: 0.0010 - 721ms/epoch - 1ms/step
# Época 2
# 645/645 - 1s - loss: 8.6562e-04 - 702ms/epoch - 1ms/step
# Época 3
# 645/645 - 1s - loss: 7.9476e-04 - 719ms/epoch - 1ms/step
# Época 4
# 645/645 - 1s - loss: 7.5150e-04 - 726ms/epoch - 1ms/step
# Época 5
# 645/645 - 1s - loss: 7.2135e-04 - 711ms/epoch - 1ms/step
# Época 6
# 645/645 - 1s - loss: 6.9667e-04 - 681ms/epoch - 1ms/step
# Época 7
# 645/645 - 1s - loss: 6.7385e-04 - 1s/epoch - 2ms/step
# Época 8
# 645/645 - 1s - loss: 6.5117e-04 - 755ms/epoch - 1ms/step
# Época 9
# 645/645 - 1s - loss: 6.2784e-04 - 799ms/epoch - 1ms/step
# Época 10
# 645/645 - 1s - loss: 6.0349e-04 - 705ms/epoch - 1ms/step
# Época 11
# 645/645 - 1s - loss: 5.7795e-04 - 699ms/epoch - 1ms/step
# Época 12
# 645/645 - 1s - loss: 5.5118e-04 - 708ms/epoch - 1ms/step
# Época 13
# 645/645 - 1s - loss: 5.2326e-04 - 688ms/epoch - 1ms/step
# Época 14
# 645/645 - 1s - loss: 4.9448e-04 - 701ms/epoch - 1ms/step
# Época 15
# 645/645 - 1s - loss: 4.6547e-04 - 701ms/epoch - 1ms/step
# Época 16
# 645/645 - 1s - loss: 4.3825e-04 - 698ms/epoch - 1ms/step
# Época 17
# 645/645 - 1s - loss: 4.2466e-04 - 707ms/epoch - 1ms/step
# Época 18
# 645/645 - 1s - loss: 4.2091e-04 - 700ms/epoch - 1ms/step
# Época 19
# 645/645 - 1s - loss: 4.1068e-04 - 974ms/epoch - 2ms/step
# Época 20
# 645/645 - 1s - loss: 3.9807e-04 - 815ms/epoch - 1ms/step
# Época 21
# 645/645 - 1s - loss: 3.8485e-04 - 704ms/epoch - 1ms/step
# Época 22
# 645/645 - 1s - loss: 3.7269e-04 - 703ms/epoch - 1ms/step
# Época 23
# 645/645 - 1s - loss: 3.6253e-04 - 721ms/epoch - 1ms/step
# Época 24
# 645/645 - 1s - loss: 3.5436e-04 - 867ms/epoch - 1ms/step
# Época 25
# 645/645 - 1s - loss: 3.4786e-04 - 1s/epoch - 2ms/step
# Época 26
# 645/645 - 1s - loss: 3.4274e-04 - 724ms/epoch - 1ms/step
# Época 27
# 645/645 - 1s - loss: 3.3878e-04 - 712ms/epoch - 1ms/step
# Época 28
# 645/645 - 1s - loss: 3.3580e-04 - 852ms/epoch - 1ms/step
# Época 29
# 645/645 - 2s - loss: 3.3365e-04 - 2s/epoch - 3ms/step
# Época 30
# 645/645 - 1s - loss: 3.3216e-04 - 732ms/epoch - 1ms/step
# Época 31
# 645/645 - 1s - loss: 3.3118e-04 - 736ms/epoch - 1ms/step
# Época 32
# 645/645 - 1s - loss: 3.3056e-04 - 709ms/epoch - 1ms/step
# Época 33
# 645/645 - 1s - loss: 3.3017e-04 - 735ms/epoch - 1ms/step
# Época 34
# 645/645 - 1s - loss: 3.2992e-04 - 737ms/epoch - 1ms/step
# Época 35
# 645/645 - 1s - loss: 3.2976e-04 - 949ms/epoch - 1ms/step
# Época 36
# 645/645 - 1s - loss: 3.2966e-04 - 1s/epoch - 2ms/step
# Época 37
# 645/645 - 1s - loss: 3.2961e-04 - 1s/epoch - 2ms/step
# Época 38
# 645/645 - 2s - loss: 3.2955e-04 - 2s/epoch - 3ms/step
# Época 39
# 645/645 - 1s - loss: 3.2949e-04 - 723ms/epoch - 1ms/step
# Época 40
# 645/645 - 1s - loss: 3.2943e-04 - 704ms/epoch - 1ms/step
# Época 41
# 645/645 - 1s - loss: 3.2922e-04 - 715ms/epoch - 1ms/step
# Época 42
# 645/645 - 1s - loss: 3.2847e-04 - 717ms/epoch - 1ms/step
# Época 43
# 645/645 - 1s - loss: 3.2701e-04 - 711ms/epoch - 1ms/step
# Época 44
# 645/645 - 1s - loss: 3.2543e-04 - 701ms/epoch - 1ms/step
# Época 45
# 645/645 - 1s - loss: 3.2460e-04 - 732ms/epoch - 1ms/step
# Época 46
# 645/645 - 1s - loss: 3.2436e-04 - 710ms/epoch - 1ms/step
# Época 47
# 645/645 - 1s - loss: 3.2447e-04 - 733ms/epoch - 1ms/step
# Época 48
# 645/645 - 1s - loss: 3.2474e-04 - 988ms/epoch - 2ms/step
# Época 49
# 645/645 - 1s - loss: 3.2506e-04 - 731ms/epoch - 1ms/step
# Época 50
# 645/645 - 1s - loss: 3.2542e-04 - 719ms/epoch - 1ms/step
# Época 51
# 645/645 - 1s - loss: 3.2578e-04 - 699ms/epoch - 1ms/step
# Época 52
# 645/645 - 1s - loss: 3.2615e-04 - 717ms/epoch - 1ms/step
# Época 53
# 645/645 - 1s - loss: 3.2651e-04 - 710ms/epoch - 1ms/step
# Época 54
# 645/645 - 1s - loss: 3.2687e-04 - 720ms/epoch - 1ms/step
# Época 55
# 645/645 - 1s - loss: 3.2726e-04 - 718ms/epoch - 1ms/step
# Época 56
# 645/645 - 1s - loss: 3.2771e-04 - 729ms/epoch - 1ms/step
# Época 57
# 645/645 - 1s - loss: 3.2826e-04 - 731ms/epoch - 1ms/step
# Época 58
# 645/645 - 1s - loss: 3.2894e-04 - 714ms/epoch - 1ms/step
# Época 59
# 645/645 - 1s - loss: 3.2978e-04 - 966ms/epoch - 1ms/step
# Época 60
# 645/645 - 1s - loss: 3.3080e-04 - 756ms/epoch - 1ms/step
# Época 61
# 645/645 - 1s - loss: 3.3202e-04 - 736ms/epoch - 1ms/step
# Época 62
# 645/645 - 1s - loss: 3.3344e-04 - 726ms/epoch - 1ms/step
# Época 63
# 645/645 - 1s - loss: 3.3508e-04 - 723ms/epoch - 1ms/step
# Época 64
# 645/645 - 1s - loss: 3.3695e-04 - 690ms/epoch - 1ms/step
# Época 65
# 645/645 - 1s - loss: 3.3904e-04 - 711ms/epoch - 1ms/step
# Época 66
# 645/645 - 1s - loss: 3.4132e-04 - 786ms/epoch - 1ms/step
# Época 67
# 645/645 - 1s - loss: 3.4371e-04 - 864ms/epoch - 1ms/step
# Época 68
# 645/645 - 1s - loss: 3.4611e-04 - 907ms/epoch - 1ms/step
# Época 69
# 645/645 - 1s - loss: 3.4845e-04 - 993ms/epoch - 2ms/step
# Época 70
# 645/645 - 1s - loss: 3.5069e-04 - 910ms/epoch - 1ms/step
# Época 71
# 645/645 - 1s - loss: 3.5287e-04 - 772ms/epoch - 1ms/step
# Época 72
# 645/645 - 1s - loss: 3.5504e-04 - 811ms/epoch - 1ms/step
# Época 73
# 645/645 - 1s - loss: 3.5727e-04 - 776ms/epoch - 1ms/step
# Época 74
# 645/645 - 1s - loss: 3.5952e-04 - 786ms/epoch - 1ms/step
# Época 75
# 645/645 - 1s - loss: 3.6168e-04 - 781ms/epoch - 1ms/step
# Época 76
# 645/645 - 1s - loss: 3.6359e-04 - 864ms/epoch - 1ms/step
# Época 77
# 645/645 - 1s - loss: 3.6508e-04 - 825ms/epoch - 1ms/step
# Época 78
# 645/645 - 1s - loss: 3.6603e-04 - 859ms/epoch - 1ms/step
# Época 79
# 645/645 - 1s - loss: 3.6638e-04 - 941ms/epoch - 1ms/step
# Época 80
# 645/645 - 1s - loss: 3.6607e-04 - 1s/epoch - 2ms/step
# Época 81
# 645/645 - 1s - loss: 3.6519e-04 - 818ms/epoch - 1ms/step
# Época 82
# 645/645 - 1s - loss: 3.6397e-04 - 1s/epoch - 2ms/step
# Época 83
# 645/645 - 1s - loss: 3.6277e-04 - 1s/epoch - 2ms/step
# Época 84
# 645/645 - 1s - loss: 3.6184e-04 - 747ms/epoch - 1ms/step
# Época 85
# 645/645 - 1s - loss: 3.6122e-04 - 750ms/epoch - 1ms/step
# Época 86
# 645/645 - 1s - loss: 3.6079e-04 - 815ms/epoch - 1ms/step
# Época 87
# 645/645 - 1s - loss: 3.6042e-04 - 1s/epoch - 2ms/step
# Época 88
# 645/645 - 1s - loss: 3.6003e-04 - 914ms/epoch - 1ms/step
# Época 89
# 645/645 - 1s - loss: 3.5961e-04 - 1s/epoch - 2ms/step
# Época 90
# 645/645 - 1s - loss: 3.5917e-04 - 773ms/epoch - 1ms/step
# Época 91
# 645/645 - 1s - loss: 3.5873e-04 - 790ms/epoch - 1ms/step
# Época 92
# 645/645 - 1s - loss: 3.5832e-04 - 786ms/epoch - 1ms/step
# Época 93
# 645/645 - 1s - loss: 3.5792e-04 - 755ms/epoch - 1ms/step
# Época 94
# 645/645 - 1s - loss: 3.5755e-04 - 735ms/epoch - 1ms/step
# Época 95
# 645/645 - 1s - loss: 3.5722e-04 - 822ms/epoch - 1ms/step
# Época 96
# 645/645 - 1s - loss: 3.5692e-04 - 1s/epoch - 2ms/step
# Época 97
# 645/645 - 1s - loss: 3.5663e-04 - 948ms/epoch - 1ms/step
# Época 98
# 645/645 - 1s - loss: 3.5636e-04 - 791ms/epoch - 1ms/step
# Época 99
# 645/645 - 1s - loss: 3.5609e-04 - 933ms/epoch - 1ms/step

# %% [markdown]
# Una vez ajustado el modelo, podemos estimar su rendimiento en los conjuntos de datos de entrenamiento y de test. Esto nos dará un punto de comparación para los nuevos modelos.
#
# Hay que tener en cuenta que invertimos las predicciones antes de calcular las puntuaciones de error para asegurarnos de que el rendimiento se presenta en las mismas unidades que los datos originales (miles de pasajeros al mes).

# %%
# Realizar las predicciones
trainPredict = model.predict(trainX,batch_size=batch_size)
testPredict = model.predict(testX,batch_size=batch_size)
# Deshacer la normalización
trainPredict = scaler.inverse_transform(trainPredict)
trainYOriginal = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testYOriginal = scaler.inverse_transform([testY])
# Calcular los error
trainScore = math.sqrt(mean_squared_error(trainYOriginal[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testYOriginal[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 645/645 [==============================] - 1s 1ms/step
# 317/317 [==============================] - 0s 1ms/step
# Train Score: 56.80 RMSE
# Test Score: 66.35 RMSE

# %% [markdown]
# Por último, podemos generar predicciones utilizando el modelo para el conjunto de datos de entrenamiento y de test para obtener una indicación visual de la habilidad del modelo.
#
# Debido a la forma en que se preparó el conjunto de datos, debemos desplazar las predicciones para que se alineen en el eje x con el conjunto de datos original. Una vez preparados, los datos se representan, mostrando el conjunto de datos original en azul, las predicciones del conjunto de datos de entrenamiento en verde y las predicciones del conjunto de datos de prueba no visto en rojo.

# %%
# Hacer un shift de las predicciones de entrenamiento para el plot
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# Hacer un shift de las predicciones de test para el plot
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# Representar las predicciones
plt.title("Plot baseline and predictions")

plt.legend(['Dataset', 'Train', 'Test', 'Predicciones Train', 'Predicciones Test'])

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Como podemos ver, la red ha hecho un buen trabajo, aunque las predicciones empiezan a desviarse al final.
#
# ---

# %% [markdown]
# # Experimentación
#
# Para realizar una experimentación y poder compararlo con el modelo anterior se deben cambiar los parámetros uno a uno para así poder saber si el cambio ha realizado una mejora o un empeoramiento en el modelo. Si se realizan varios cambios en los hiperparámetros es difícil saber cuál ha sido el que ha podido producir más o menos mejora o empeoramiento.
#
# Por eso se realizarán 3 experimentos:
# - Cambio de batch
# - Cambio de número de neuronas
# - Cambio de epochs
#
# ## Función
#
# Para facilitar la experimentación se va a crear una función cuyos inputs son los parámetros con los que se va a experimentar, en el enunciado del ejercicio venían descritos unos valores que no se corresponden con los de este notebook, por lo que primero se va a ejecutar la función con los valores predeterminados según el enunciado y a partir de ahí se modificarán.
#
# Sin embargo, se dice que el batch size establecido es 500 sin embargo este valor da un error al provocar una diferencia entre los shapes que se introducen al modelo. También puede dar error si se introdce un número demasiado grande y no puede ser alojado en memoria, tras realizar unas pruebas el número que no ha dado error ha sido 4.
#
# Entre otros errores se encuentra:
# ValueError: Found input variables with inconsistent numbers of samples: [645, 648]
# Dado porque X e Y tienen diferentes tamaños, al comprobarlo:

# %%
print(trainX.shape)
print(trainY.shape)

# %% [markdown]
# Tras realizar varios experimentos, los batches están dando el problema de que no terminar el conjunto de datos de entrenamiento, por lo que si en entrenamiento hay X muestras, el número de batch debe ser uno que sea módulo.
#
# Es decir trainX.shape % X == 0
#
# Con 4 da error, y con 2 también. El número con el que funcionará siempre será 1, por lo que este será el número que se establecerá como predeterminado.

# %%
def experiment_recurrent_neural_network(batch=1, LSTM_neurons = 32, n_epochs = 100):
  # Tamaño de batch
  batch_size=batch

  # Crear un modelo secuencial
  model = Sequential()

  # Crear una capa LSTM
  model.add(LSTM(LSTM_neurons, batch_input_shape=(batch_size, look_back, 1), stateful=True))

  # Crear una capa densa
  model.add(Dense(1))

  # Compilar el modelo
  model.compile(optimizer="adam", loss='mean_squared_error')

  # Entrenamiento habitual (no resetearía el estado)
  # model.fit(trainX, trainY, epochs=30, batch_size=1)

  # Entrenar el modelo con reseteo explícito
  for i in range(n_epochs):
    print('Época %d'%(i))
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
    model.reset_states()

  # Realizar las predicciones
  trainPredict = model.predict(trainX,batch_size=batch_size)
  testPredict = model.predict(testX,batch_size=batch_size)
  # Deshacer la normalización
  trainPredict = scaler.inverse_transform(trainPredict)
  trainYOriginal = scaler.inverse_transform([trainY])
  testPredict = scaler.inverse_transform(testPredict)
  testYOriginal = scaler.inverse_transform([testY])
  # Calcular los error
  trainScore = math.sqrt(mean_squared_error(trainYOriginal[0], trainPredict[:,0]))
  print('Train Score: %.2f RMSE' % (trainScore))
  testScore = math.sqrt(mean_squared_error(testYOriginal[0], testPredict[:,0]))
  print('Test Score: %.2f RMSE' % (testScore))


  # Hacer un shift de las predicciones de entrenamiento para el plot
  trainPredictPlot = numpy.empty_like(dataset)
  trainPredictPlot[:, :] = numpy.nan
  trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
  # Hacer un shift de las predicciones de test para el plot
  testPredictPlot = numpy.empty_like(dataset)
  testPredictPlot[:, :] = numpy.nan
  testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

  # Representar las predicciones
  plt.title("Plot baseline and predictions")
  plt.plot(scaler.inverse_transform(dataset))
  plt.plot(trainPredictPlot)
  plt.plot(testPredictPlot)
  plt.show()

# %%
experiment_recurrent_neural_network()
# Out:
# Época 0
# 645/645 - 2s - loss: 9.6248e-04 - 2s/epoch - 3ms/step
# Época 1
# 645/645 - 1s - loss: 9.7975e-04 - 774ms/epoch - 1ms/step
# Época 2
# 645/645 - 1s - loss: 8.5600e-04 - 741ms/epoch - 1ms/step
# Época 3
# 645/645 - 1s - loss: 7.9215e-04 - 762ms/epoch - 1ms/step
# Época 4
# 645/645 - 1s - loss: 7.1854e-04 - 758ms/epoch - 1ms/step
# Época 5
# 645/645 - 1s - loss: 6.3273e-04 - 744ms/epoch - 1ms/step
# Época 6
# 645/645 - 1s - loss: 5.6649e-04 - 735ms/epoch - 1ms/step
# Época 7
# 645/645 - 1s - loss: 5.1866e-04 - 861ms/epoch - 1ms/step
# Época 8
# 645/645 - 1s - loss: 5.0722e-04 - 992ms/epoch - 2ms/step
# Época 9
# 645/645 - 1s - loss: 4.2995e-04 - 750ms/epoch - 1ms/step
# Época 10
# 645/645 - 1s - loss: 3.7490e-04 - 771ms/epoch - 1ms/step
# Época 11
# 645/645 - 1s - loss: 3.3817e-04 - 735ms/epoch - 1ms/step
# Época 12
# 645/645 - 1s - loss: 3.1777e-04 - 738ms/epoch - 1ms/step
# Época 13
# 645/645 - 1s - loss: 3.0645e-04 - 746ms/epoch - 1ms/step
# Época 14
# 645/645 - 1s - loss: 2.9823e-04 - 745ms/epoch - 1ms/step
# Época 15
# 645/645 - 1s - loss: 2.9076e-04 - 760ms/epoch - 1ms/step
# Época 16
# 645/645 - 1s - loss: 2.8635e-04 - 747ms/epoch - 1ms/step
# Época 17
# 645/645 - 1s - loss: 2.8004e-04 - 792ms/epoch - 1ms/step
# Época 18
# 645/645 - 1s - loss: 2.7180e-04 - 1s/epoch - 2ms/step
# Época 19
# 645/645 - 1s - loss: 2.7435e-04 - 762ms/epoch - 1ms/step
# Época 20
# 645/645 - 1s - loss: 2.6411e-04 - 760ms/epoch - 1ms/step
# Época 21
# 645/645 - 1s - loss: 2.6168e-04 - 749ms/epoch - 1ms/step
# Época 22
# 645/645 - 1s - loss: 2.5961e-04 - 749ms/epoch - 1ms/step
# Época 23
# 645/645 - 1s - loss: 2.5628e-04 - 755ms/epoch - 1ms/step
# Época 24
# 645/645 - 1s - loss: 2.5220e-04 - 755ms/epoch - 1ms/step
# Época 25
# 645/645 - 1s - loss: 2.6427e-04 - 758ms/epoch - 1ms/step
# Época 26
# 645/645 - 1s - loss: 2.6556e-04 - 738ms/epoch - 1ms/step
# Época 27
# 645/645 - 1s - loss: 2.5576e-04 - 751ms/epoch - 1ms/step
# Época 28
# 645/645 - 1s - loss: 2.4767e-04 - 848ms/epoch - 1ms/step
# Época 29
# 645/645 - 1s - loss: 2.4312e-04 - 999ms/epoch - 2ms/step
# Época 30
# 645/645 - 1s - loss: 2.4143e-04 - 769ms/epoch - 1ms/step
# Época 31
# 645/645 - 1s - loss: 2.3936e-04 - 738ms/epoch - 1ms/step
# Época 32
# 645/645 - 1s - loss: 2.2847e-04 - 758ms/epoch - 1ms/step
# Época 33
# 645/645 - 1s - loss: 2.2700e-04 - 740ms/epoch - 1ms/step
# Época 34
# 645/645 - 1s - loss: 2.3276e-04 - 746ms/epoch - 1ms/step
# Época 35
# 645/645 - 1s - loss: 2.2627e-04 - 746ms/epoch - 1ms/step
# Época 36
# 645/645 - 1s - loss: 2.2342e-04 - 749ms/epoch - 1ms/step
# Época 37
# 645/645 - 1s - loss: 2.2117e-04 - 746ms/epoch - 1ms/step
# Época 38
# 645/645 - 1s - loss: 2.1936e-04 - 910ms/epoch - 1ms/step
# Época 39
# 645/645 - 1s - loss: 2.1710e-04 - 892ms/epoch - 1ms/step
# Época 40
# 645/645 - 1s - loss: 2.1567e-04 - 752ms/epoch - 1ms/step
# Época 41
# 645/645 - 1s - loss: 2.1436e-04 - 753ms/epoch - 1ms/step
# Época 42
# 645/645 - 1s - loss: 2.1393e-04 - 777ms/epoch - 1ms/step
# Época 43
# 645/645 - 1s - loss: 2.1318e-04 - 756ms/epoch - 1ms/step
# Época 44
# 645/645 - 1s - loss: 2.1241e-04 - 763ms/epoch - 1ms/step
# Época 45
# 645/645 - 1s - loss: 2.4868e-04 - 762ms/epoch - 1ms/step
# Época 46
# 645/645 - 1s - loss: 2.8226e-04 - 731ms/epoch - 1ms/step
# Época 47
# 645/645 - 1s - loss: 2.8295e-04 - 738ms/epoch - 1ms/step
# Época 48
# 645/645 - 1s - loss: 2.8937e-04 - 752ms/epoch - 1ms/step
# Época 49
# 645/645 - 1s - loss: 2.9178e-04 - 984ms/epoch - 2ms/step
# Época 50
# 645/645 - 1s - loss: 2.9483e-04 - 795ms/epoch - 1ms/step
# Época 51
# 645/645 - 1s - loss: 2.9925e-04 - 766ms/epoch - 1ms/step
# Época 52
# 645/645 - 1s - loss: 3.0463e-04 - 756ms/epoch - 1ms/step
# Época 53
# 645/645 - 1s - loss: 3.1052e-04 - 748ms/epoch - 1ms/step
# Época 54
# 645/645 - 1s - loss: 3.1655e-04 - 738ms/epoch - 1ms/step
# Época 55
# 645/645 - 1s - loss: 3.2253e-04 - 777ms/epoch - 1ms/step
# Época 56
# 645/645 - 1s - loss: 3.2831e-04 - 762ms/epoch - 1ms/step
# Época 57
# 645/645 - 1s - loss: 3.3336e-04 - 755ms/epoch - 1ms/step
# Época 58
# 645/645 - 1s - loss: 3.3584e-04 - 747ms/epoch - 1ms/step
# Época 59
# 645/645 - 1s - loss: 3.8747e-04 - 740ms/epoch - 1ms/step
# Época 60
# 645/645 - 1s - loss: 3.1871e-04 - 953ms/epoch - 1ms/step
# Época 61
# 645/645 - 1s - loss: 3.2712e-04 - 895ms/epoch - 1ms/step
# Época 62
# 645/645 - 1s - loss: 3.8559e-04 - 760ms/epoch - 1ms/step
# Época 63
# 645/645 - 1s - loss: 6.9625e-04 - 753ms/epoch - 1ms/step
# Época 64
# 645/645 - 1s - loss: 3.2038e-04 - 749ms/epoch - 1ms/step
# Época 65
# 645/645 - 1s - loss: 2.4137e-04 - 733ms/epoch - 1ms/step
# Época 66
# 645/645 - 1s - loss: 2.4669e-04 - 763ms/epoch - 1ms/step
# Época 67
# 645/645 - 1s - loss: 2.4880e-04 - 760ms/epoch - 1ms/step
# Época 68
# 645/645 - 1s - loss: 2.5176e-04 - 742ms/epoch - 1ms/step
# Época 69
# 645/645 - 1s - loss: 2.5655e-04 - 751ms/epoch - 1ms/step
# Época 70
# 645/645 - 1s - loss: 2.6284e-04 - 962ms/epoch - 1ms/step
# Época 71
# 645/645 - 1s - loss: 2.6941e-04 - 879ms/epoch - 1ms/step
# Época 72
# 645/645 - 1s - loss: 2.6983e-04 - 751ms/epoch - 1ms/step
# Época 73
# 645/645 - 1s - loss: 2.7672e-04 - 747ms/epoch - 1ms/step
# Época 74
# 645/645 - 1s - loss: 2.7722e-04 - 754ms/epoch - 1ms/step
# Época 75
# 645/645 - 1s - loss: 2.8951e-04 - 749ms/epoch - 1ms/step
# Época 76
# 645/645 - 1s - loss: 2.9044e-04 - 753ms/epoch - 1ms/step
# Época 77
# 645/645 - 1s - loss: 2.9120e-04 - 773ms/epoch - 1ms/step
# Época 78
# 645/645 - 1s - loss: 2.9283e-04 - 762ms/epoch - 1ms/step
# Época 79
# 645/645 - 1s - loss: 2.9513e-04 - 758ms/epoch - 1ms/step
# Época 80
# 645/645 - 1s - loss: 2.9766e-04 - 827ms/epoch - 1ms/step
# Época 81
# 645/645 - 1s - loss: 3.0039e-04 - 841ms/epoch - 1ms/step
# Época 82
# 645/645 - 1s - loss: 3.0337e-04 - 740ms/epoch - 1ms/step
# Época 83
# 645/645 - 1s - loss: 3.0664e-04 - 744ms/epoch - 1ms/step
# Época 84
# 645/645 - 1s - loss: 3.1018e-04 - 761ms/epoch - 1ms/step
# Época 85
# 645/645 - 1s - loss: 3.1401e-04 - 756ms/epoch - 1ms/step
# Época 86
# 645/645 - 1s - loss: 3.1811e-04 - 748ms/epoch - 1ms/step
# Época 87
# 645/645 - 1s - loss: 3.2252e-04 - 771ms/epoch - 1ms/step
# Época 88
# 645/645 - 1s - loss: 3.2734e-04 - 747ms/epoch - 1ms/step
# Época 89
# 645/645 - 1s - loss: 3.3274e-04 - 780ms/epoch - 1ms/step
# Época 90
# 645/645 - 1s - loss: 3.3866e-04 - 1s/epoch - 2ms/step
# Época 91
# 645/645 - 1s - loss: 3.4476e-04 - 788ms/epoch - 1ms/step
# Época 92
# 645/645 - 1s - loss: 3.5062e-04 - 786ms/epoch - 1ms/step
# Época 93
# 645/645 - 1s - loss: 3.5593e-04 - 767ms/epoch - 1ms/step
# Época 94
# 645/645 - 1s - loss: 3.6024e-04 - 744ms/epoch - 1ms/step
# Época 95
# 645/645 - 1s - loss: 3.6299e-04 - 748ms/epoch - 1ms/step
# Época 96
# 645/645 - 1s - loss: 3.6457e-04 - 749ms/epoch - 1ms/step
# Época 97
# 645/645 - 1s - loss: 3.6611e-04 - 755ms/epoch - 1ms/step
# Época 98
# 645/645 - 1s - loss: 4.3100e-04 - 754ms/epoch - 1ms/step
# Época 99
# 645/645 - 1s - loss: 4.8350e-04 - 764ms/epoch - 1ms/step
# 645/645 [==============================] - 1s 1ms/step
# 317/317 [==============================] - 0s 1ms/step
# Train Score: 5.77 RMSE
# Test Score: 116.35 RMSE

# %% [markdown]
# ## Cambio de número de batch
#
# El código a continuación da error, para demostrar que tal y como se han dado los códigos no se puede aumentar en este caso el batchsize

# %%
experiment_recurrent_neural_network(batch=128)
# Out:
# Época 0
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-59-95dfbdeb2c98> in <cell line: 1>()
# ----> 1 experiment_recurrent_neural_network(batch=128)
#
# <ipython-input-56-6d5e8981f5e1> in experiment_recurrent_neural_network(batch, LSTM_neurons, n_epochs)
#      21   for i in range(n_epochs):
#      22     print('Época %d'%(i))
# ---> 23     model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
#      24     model.reset_states()
#      25
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node while/add defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-59-95dfbdeb2c98>", line 1, in <cell line: 1>
#
#   File "<ipython-input-56-6d5e8981f5e1>", line 23, in experiment_recurrent_neural_network
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/sequential.py", line 398, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/base_rnn.py", line 556, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py", line 749, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py", line 1339, in lstm_with_backend_selection
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py", line 981, in standard_lstm
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5168, in rnn
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5147, in _step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py", line 968, in step
#
# Incompatible shapes: [5,128] vs. [128,128]
# 	 [[{{node while/add}}]]
# 	 [[sequential_17/lstm_17/PartitionedCall]] [Op:__inference_train_function_774320]

# %% [markdown]
# ## Cambiar número de LSTM neurons
#
# Vamos a cambiar a un número mayor, a 64

# %%
experiment_recurrent_neural_network(batch=1, LSTM_neurons = 64)
# Out:
# Época 0
# 645/645 - 2s - loss: 0.0012 - 2s/epoch - 3ms/step
# Época 1
# 645/645 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Época 2
# 645/645 - 1s - loss: 0.0011 - 845ms/epoch - 1ms/step
# Época 3
# 645/645 - 2s - loss: 0.0012 - 2s/epoch - 3ms/step
# Época 4
# 645/645 - 1s - loss: 0.0012 - 763ms/epoch - 1ms/step
# Época 5
# 645/645 - 1s - loss: 8.8346e-04 - 755ms/epoch - 1ms/step
# Época 6
# 645/645 - 1s - loss: 7.6500e-04 - 994ms/epoch - 2ms/step
# Época 7
# 645/645 - 1s - loss: 6.4950e-04 - 757ms/epoch - 1ms/step
# Época 8
# 645/645 - 1s - loss: 5.6322e-04 - 747ms/epoch - 1ms/step
# Época 9
# 645/645 - 1s - loss: 4.9165e-04 - 770ms/epoch - 1ms/step
# Época 10
# 645/645 - 1s - loss: 4.3633e-04 - 746ms/epoch - 1ms/step
# Época 11
# 645/645 - 1s - loss: 3.9909e-04 - 765ms/epoch - 1ms/step
# Época 12
# 645/645 - 1s - loss: 3.7398e-04 - 760ms/epoch - 1ms/step
# Época 13
# 645/645 - 1s - loss: 3.5706e-04 - 783ms/epoch - 1ms/step
# Época 14
# 645/645 - 1s - loss: 3.4728e-04 - 768ms/epoch - 1ms/step
# Época 15
# 645/645 - 1s - loss: 3.4312e-04 - 762ms/epoch - 1ms/step
# Época 16
# 645/645 - 1s - loss: 3.4265e-04 - 873ms/epoch - 1ms/step
# Época 17
# 645/645 - 1s - loss: 3.4430e-04 - 760ms/epoch - 1ms/step
# Época 18
# 645/645 - 1s - loss: 3.4743e-04 - 758ms/epoch - 1ms/step
# Época 19
# 645/645 - 1s - loss: 3.5224e-04 - 747ms/epoch - 1ms/step
# Época 20
# 645/645 - 1s - loss: 3.5811e-04 - 785ms/epoch - 1ms/step
# Época 21
# 645/645 - 1s - loss: 3.5997e-04 - 744ms/epoch - 1ms/step
# Época 22
# 645/645 - 1s - loss: 3.6326e-04 - 752ms/epoch - 1ms/step
# Época 23
# 645/645 - 1s - loss: 3.6888e-04 - 777ms/epoch - 1ms/step
# Época 24
# 645/645 - 1s - loss: 3.7139e-04 - 785ms/epoch - 1ms/step
# Época 25
# 645/645 - 1s - loss: 3.7932e-04 - 778ms/epoch - 1ms/step
# Época 26
# 645/645 - 1s - loss: 3.7986e-04 - 781ms/epoch - 1ms/step
# Época 27
# 645/645 - 1s - loss: 3.9416e-04 - 959ms/epoch - 1ms/step
# Época 28
# 645/645 - 1s - loss: 3.8069e-04 - 878ms/epoch - 1ms/step
# Época 29
# 645/645 - 1s - loss: 3.9319e-04 - 758ms/epoch - 1ms/step
# Época 30
# 645/645 - 1s - loss: 3.9178e-04 - 734ms/epoch - 1ms/step
# Época 31
# 645/645 - 1s - loss: 3.8106e-04 - 764ms/epoch - 1ms/step
# Época 32
# 645/645 - 1s - loss: 3.8281e-04 - 763ms/epoch - 1ms/step
# Época 33
# 645/645 - 1s - loss: 3.8202e-04 - 761ms/epoch - 1ms/step
# Época 34
# 645/645 - 1s - loss: 3.7868e-04 - 738ms/epoch - 1ms/step
# Época 35
# 645/645 - 1s - loss: 3.7231e-04 - 757ms/epoch - 1ms/step
# Época 36
# 645/645 - 1s - loss: 3.6818e-04 - 737ms/epoch - 1ms/step
# Época 37
# 645/645 - 1s - loss: 3.6077e-04 - 771ms/epoch - 1ms/step
# Época 38
# 645/645 - 1s - loss: 3.6178e-04 - 901ms/epoch - 1ms/step
# Época 39
# 645/645 - 1s - loss: 3.6416e-04 - 996ms/epoch - 2ms/step
# Época 40
# 645/645 - 1s - loss: 3.5364e-04 - 757ms/epoch - 1ms/step
# Época 41
# 645/645 - 1s - loss: 3.4794e-04 - 757ms/epoch - 1ms/step
# Época 42
# 645/645 - 1s - loss: 3.5150e-04 - 747ms/epoch - 1ms/step
# Época 43
# 645/645 - 1s - loss: 3.4695e-04 - 784ms/epoch - 1ms/step
# Época 44
# 645/645 - 1s - loss: 3.4173e-04 - 774ms/epoch - 1ms/step
# Época 45
# 645/645 - 1s - loss: 3.5140e-04 - 756ms/epoch - 1ms/step
# Época 46
# 645/645 - 1s - loss: 3.4135e-04 - 776ms/epoch - 1ms/step
# Época 47
# 645/645 - 1s - loss: 3.3696e-04 - 741ms/epoch - 1ms/step
# Época 48
# 645/645 - 1s - loss: 3.4132e-04 - 758ms/epoch - 1ms/step
# Época 49
# 645/645 - 1s - loss: 3.3576e-04 - 770ms/epoch - 1ms/step
# Época 50
# 645/645 - 1s - loss: 3.3480e-04 - 963ms/epoch - 1ms/step
# Época 51
# 645/645 - 1s - loss: 3.3342e-04 - 882ms/epoch - 1ms/step
# Época 52
# 645/645 - 1s - loss: 3.3461e-04 - 745ms/epoch - 1ms/step
# Época 53
# 645/645 - 1s - loss: 3.3578e-04 - 743ms/epoch - 1ms/step
# Época 54
# 645/645 - 1s - loss: 3.3201e-04 - 775ms/epoch - 1ms/step
# Época 55
# 645/645 - 1s - loss: 3.3042e-04 - 796ms/epoch - 1ms/step
# Época 56
# 645/645 - 1s - loss: 3.2773e-04 - 764ms/epoch - 1ms/step
# Época 57
# 645/645 - 1s - loss: 3.2914e-04 - 762ms/epoch - 1ms/step
# Época 58
# 645/645 - 1s - loss: 3.3235e-04 - 768ms/epoch - 1ms/step
# Época 59
# 645/645 - 1s - loss: 3.2994e-04 - 773ms/epoch - 1ms/step
# Época 60
# 645/645 - 1s - loss: 3.2990e-04 - 818ms/epoch - 1ms/step
# Época 61
# 645/645 - 1s - loss: 3.2947e-04 - 809ms/epoch - 1ms/step
# Época 62
# 645/645 - 1s - loss: 3.2675e-04 - 734ms/epoch - 1ms/step
# Época 63
# 645/645 - 1s - loss: 3.3389e-04 - 758ms/epoch - 1ms/step
# Época 64
# 645/645 - 1s - loss: 3.2397e-04 - 752ms/epoch - 1ms/step
# Época 65
# 645/645 - 1s - loss: 3.2696e-04 - 770ms/epoch - 1ms/step
# Época 66
# 645/645 - 1s - loss: 3.2394e-04 - 773ms/epoch - 1ms/step
# Época 67
# 645/645 - 1s - loss: 3.2577e-04 - 759ms/epoch - 1ms/step
# Época 68
# 645/645 - 1s - loss: 3.2210e-04 - 776ms/epoch - 1ms/step
# Época 69
# 645/645 - 1s - loss: 3.2150e-04 - 751ms/epoch - 1ms/step
# Época 70
# 645/645 - 1s - loss: 3.3408e-04 - 846ms/epoch - 1ms/step
# Época 71
# 645/645 - 1s - loss: 3.3397e-04 - 788ms/epoch - 1ms/step
# Época 72
# 645/645 - 1s - loss: 3.1933e-04 - 764ms/epoch - 1ms/step
# Época 73
# 645/645 - 1s - loss: 3.0787e-04 - 763ms/epoch - 1ms/step
# Época 74
# 645/645 - 1s - loss: 3.0188e-04 - 757ms/epoch - 1ms/step
# Época 75
# 645/645 - 1s - loss: 2.9254e-04 - 759ms/epoch - 1ms/step
# Época 76
# 645/645 - 1s - loss: 2.9162e-04 - 779ms/epoch - 1ms/step
# Época 77
# 645/645 - 1s - loss: 2.8130e-04 - 791ms/epoch - 1ms/step
# Época 78
# 645/645 - 1s - loss: 2.7973e-04 - 757ms/epoch - 1ms/step
# Época 79
# 645/645 - 1s - loss: 2.8011e-04 - 764ms/epoch - 1ms/step
# Época 80
# 645/645 - 1s - loss: 2.7468e-04 - 745ms/epoch - 1ms/step
# Época 81
# 645/645 - 1s - loss: 2.8769e-04 - 855ms/epoch - 1ms/step
# Época 82
# 645/645 - 1s - loss: 2.8602e-04 - 1s/epoch - 2ms/step
# Época 83
# 645/645 - 1s - loss: 2.7984e-04 - 747ms/epoch - 1ms/step
# Época 84
# 645/645 - 1s - loss: 2.6757e-04 - 800ms/epoch - 1ms/step
# Época 85
# 645/645 - 1s - loss: 2.6822e-04 - 728ms/epoch - 1ms/step
# Época 86
# 645/645 - 1s - loss: 2.6916e-04 - 742ms/epoch - 1ms/step
# Época 87
# 645/645 - 1s - loss: 2.6680e-04 - 760ms/epoch - 1ms/step
# Época 88
# 645/645 - 1s - loss: 2.6701e-04 - 756ms/epoch - 1ms/step
# Época 89
# 645/645 - 1s - loss: 2.7248e-04 - 748ms/epoch - 1ms/step
# Época 90
# 645/645 - 1s - loss: 2.6732e-04 - 787ms/epoch - 1ms/step
# Época 91
# 645/645 - 1s - loss: 2.6085e-04 - 755ms/epoch - 1ms/step
# Época 92
# 645/645 - 1s - loss: 2.5252e-04 - 889ms/epoch - 1ms/step
# Época 93
# 645/645 - 1s - loss: 2.4202e-04 - 778ms/epoch - 1ms/step
# Época 94
# 645/645 - 1s - loss: 2.3672e-04 - 759ms/epoch - 1ms/step
# Época 95
# 645/645 - 1s - loss: 2.2966e-04 - 764ms/epoch - 1ms/step
# Época 96
# 645/645 - 1s - loss: 2.2712e-04 - 756ms/epoch - 1ms/step
# Época 97
# 645/645 - 1s - loss: 2.2535e-04 - 759ms/epoch - 1ms/step
# Época 98
# 645/645 - 1s - loss: 2.2411e-04 - 781ms/epoch - 1ms/step
# Época 99
# 645/645 - 1s - loss: 2.2350e-04 - 763ms/epoch - 1ms/step
# 645/645 [==============================] - 1s 980us/step
# 317/317 [==============================] - 0s 947us/step
# Train Score: 3.95 RMSE
# Test Score: 10.64 RMSE

# %% [markdown]
# En este caso train score ha disminuído un poco, pero en el caso de test ha disminuído mucho.

# %% [markdown]
# ## Cambio de epochs
#
# Ahora vamos a aumentar el número de épocas a 300

# %%
experiment_recurrent_neural_network(n_epochs = 300)
# Out:
# Época 0
# 645/645 - 41s - loss: 9.3493e-04 - 41s/epoch - 64ms/step
# Época 1
# 645/645 - 1s - loss: 0.0011 - 780ms/epoch - 1ms/step
# Época 2
# 645/645 - 1s - loss: 9.7792e-04 - 816ms/epoch - 1ms/step
# Época 3
# 645/645 - 1s - loss: 8.8379e-04 - 799ms/epoch - 1ms/step
# Época 4
# 645/645 - 1s - loss: 7.7912e-04 - 767ms/epoch - 1ms/step
# Época 5
# 645/645 - 1s - loss: 6.7340e-04 - 807ms/epoch - 1ms/step
# Época 6
# 645/645 - 1s - loss: 5.3210e-04 - 810ms/epoch - 1ms/step
# Época 7
# 645/645 - 1s - loss: 4.0266e-04 - 790ms/epoch - 1ms/step
# Época 8
# 645/645 - 1s - loss: 2.9941e-04 - 790ms/epoch - 1ms/step
# Época 9
# 645/645 - 1s - loss: 2.4732e-04 - 909ms/epoch - 1ms/step
# Época 10
# 645/645 - 1s - loss: 2.3289e-04 - 748ms/epoch - 1ms/step
# Época 11
# 645/645 - 1s - loss: 2.3299e-04 - 804ms/epoch - 1ms/step
# Época 12
# 645/645 - 1s - loss: 2.3678e-04 - 775ms/epoch - 1ms/step
# Época 13
# 645/645 - 1s - loss: 2.4850e-04 - 769ms/epoch - 1ms/step
# Época 14
# 645/645 - 1s - loss: 2.6355e-04 - 789ms/epoch - 1ms/step
# Época 15
# 645/645 - 1s - loss: 2.5961e-04 - 771ms/epoch - 1ms/step
# Época 16
# 645/645 - 1s - loss: 2.5560e-04 - 768ms/epoch - 1ms/step
# Época 17
# 645/645 - 1s - loss: 2.5957e-04 - 792ms/epoch - 1ms/step
# Época 18
# 645/645 - 1s - loss: 2.5699e-04 - 823ms/epoch - 1ms/step
# Época 19
# 645/645 - 1s - loss: 2.4788e-04 - 1s/epoch - 2ms/step
# Época 20
# 645/645 - 1s - loss: 2.4095e-04 - 829ms/epoch - 1ms/step
# Época 21
# 645/645 - 1s - loss: 2.3379e-04 - 777ms/epoch - 1ms/step
# Época 22
# 645/645 - 1s - loss: 2.2907e-04 - 788ms/epoch - 1ms/step
# Época 23
# 645/645 - 1s - loss: 2.2481e-04 - 783ms/epoch - 1ms/step
# Época 24
# 645/645 - 1s - loss: 2.2191e-04 - 821ms/epoch - 1ms/step
# Época 25
# 645/645 - 1s - loss: 2.1947e-04 - 810ms/epoch - 1ms/step
# Época 26
# 645/645 - 1s - loss: 2.1674e-04 - 784ms/epoch - 1ms/step
# Época 27
# 645/645 - 1s - loss: 2.1438e-04 - 789ms/epoch - 1ms/step
# Época 28
# 645/645 - 1s - loss: 2.1218e-04 - 751ms/epoch - 1ms/step
# Época 29
# 645/645 - 1s - loss: 2.1002e-04 - 972ms/epoch - 2ms/step
# Época 30
# 645/645 - 1s - loss: 2.0810e-04 - 802ms/epoch - 1ms/step
# Época 31
# 645/645 - 1s - loss: 2.0647e-04 - 771ms/epoch - 1ms/step
# Época 32
# 645/645 - 1s - loss: 2.0514e-04 - 803ms/epoch - 1ms/step
# Época 33
# 645/645 - 1s - loss: 2.0405e-04 - 758ms/epoch - 1ms/step
# Época 34
# 645/645 - 1s - loss: 2.0313e-04 - 794ms/epoch - 1ms/step
# Época 35
# 645/645 - 1s - loss: 2.0232e-04 - 771ms/epoch - 1ms/step
# Época 36
# 645/645 - 1s - loss: 2.0165e-04 - 759ms/epoch - 1ms/step
# Época 37
# 645/645 - 1s - loss: 2.0122e-04 - 776ms/epoch - 1ms/step
# Época 38
# 645/645 - 1s - loss: 2.0125e-04 - 779ms/epoch - 1ms/step
# Época 39
# 645/645 - 1s - loss: 2.0190e-04 - 812ms/epoch - 1ms/step
# Época 40
# 645/645 - 1s - loss: 2.0312e-04 - 884ms/epoch - 1ms/step
# Época 41
# 645/645 - 1s - loss: 2.0456e-04 - 776ms/epoch - 1ms/step
# Época 42
# 645/645 - 1s - loss: 2.0589e-04 - 760ms/epoch - 1ms/step
# Época 43
# 645/645 - 1s - loss: 2.0701e-04 - 819ms/epoch - 1ms/step
# Época 44
# 645/645 - 1s - loss: 2.0788e-04 - 823ms/epoch - 1ms/step
# Época 45
# 645/645 - 1s - loss: 2.0850e-04 - 772ms/epoch - 1ms/step
# Época 46
# 645/645 - 1s - loss: 2.0894e-04 - 787ms/epoch - 1ms/step
# Época 47
# 645/645 - 1s - loss: 2.0929e-04 - 815ms/epoch - 1ms/step
# Época 48
# 645/645 - 1s - loss: 2.0959e-04 - 808ms/epoch - 1ms/step
# Época 49
# 645/645 - 1s - loss: 2.0985e-04 - 966ms/epoch - 1ms/step
# Época 50
# 645/645 - 1s - loss: 2.1010e-04 - 983ms/epoch - 2ms/step
# Época 51
# 645/645 - 1s - loss: 2.1035e-04 - 787ms/epoch - 1ms/step
# Época 52
# 645/645 - 1s - loss: 2.1064e-04 - 770ms/epoch - 1ms/step
# Época 53
# 645/645 - 1s - loss: 2.1098e-04 - 773ms/epoch - 1ms/step
# Época 54
# 645/645 - 1s - loss: 2.1141e-04 - 799ms/epoch - 1ms/step
# Época 55
# 645/645 - 1s - loss: 2.1193e-04 - 795ms/epoch - 1ms/step
# Época 56
# 645/645 - 1s - loss: 2.1244e-04 - 797ms/epoch - 1ms/step
# Época 57
# 645/645 - 1s - loss: 2.1300e-04 - 827ms/epoch - 1ms/step
# Época 58
# 645/645 - 1s - loss: 2.1405e-04 - 805ms/epoch - 1ms/step
# Época 59
# 645/645 - 1s - loss: 2.1089e-04 - 897ms/epoch - 1ms/step
# Época 60
# 645/645 - 1s - loss: 2.1562e-04 - 1s/epoch - 2ms/step
# Época 61
# 645/645 - 1s - loss: 2.1487e-04 - 783ms/epoch - 1ms/step
# Época 62
# 645/645 - 1s - loss: 2.1624e-04 - 765ms/epoch - 1ms/step
# Época 63
# 645/645 - 1s - loss: 2.1504e-04 - 767ms/epoch - 1ms/step
# Época 64
# 645/645 - 1s - loss: 2.1909e-04 - 790ms/epoch - 1ms/step
# Época 65
# 645/645 - 1s - loss: 2.1975e-04 - 781ms/epoch - 1ms/step
# Época 66
# 645/645 - 1s - loss: 2.2126e-04 - 779ms/epoch - 1ms/step
# Época 67
# 645/645 - 1s - loss: 2.2269e-04 - 770ms/epoch - 1ms/step
# Época 68
# 645/645 - 1s - loss: 2.2468e-04 - 828ms/epoch - 1ms/step
# Época 69
# 645/645 - 1s - loss: 2.2689e-04 - 794ms/epoch - 1ms/step
# Época 70
# 645/645 - 1s - loss: 2.2952e-04 - 1s/epoch - 2ms/step
# Época 71
# 645/645 - 1s - loss: 2.3229e-04 - 775ms/epoch - 1ms/step
# Época 72
# 645/645 - 1s - loss: 2.3531e-04 - 750ms/epoch - 1ms/step
# Época 73
# 645/645 - 1s - loss: 2.3843e-04 - 794ms/epoch - 1ms/step
# Época 74
# 645/645 - 1s - loss: 2.4177e-04 - 775ms/epoch - 1ms/step
# Época 75
# 645/645 - 1s - loss: 2.4522e-04 - 787ms/epoch - 1ms/step
# Época 76
# 645/645 - 1s - loss: 2.4883e-04 - 805ms/epoch - 1ms/step
# Época 77
# 645/645 - 1s - loss: 2.5249e-04 - 775ms/epoch - 1ms/step
# Época 78
# 645/645 - 1s - loss: 2.5619e-04 - 791ms/epoch - 1ms/step
# Época 79
# 645/645 - 1s - loss: 2.5987e-04 - 873ms/epoch - 1ms/step
# Época 80
# 645/645 - 1s - loss: 2.6353e-04 - 859ms/epoch - 1ms/step
# Época 81
# 645/645 - 1s - loss: 2.6721e-04 - 782ms/epoch - 1ms/step
# Época 82
# 645/645 - 1s - loss: 2.7100e-04 - 774ms/epoch - 1ms/step
# Época 83
# 645/645 - 1s - loss: 2.7530e-04 - 755ms/epoch - 1ms/step
# Época 84
# 645/645 - 1s - loss: 2.7966e-04 - 786ms/epoch - 1ms/step
# Época 85
# 645/645 - 1s - loss: 2.8269e-04 - 829ms/epoch - 1ms/step
# Época 86
# 645/645 - 1s - loss: 2.8837e-04 - 791ms/epoch - 1ms/step
# Época 87
# 645/645 - 1s - loss: 2.9077e-04 - 796ms/epoch - 1ms/step
# Época 88
# 645/645 - 1s - loss: 3.0090e-04 - 820ms/epoch - 1ms/step
# Época 89
# 645/645 - 1s - loss: 3.1329e-04 - 1s/epoch - 2ms/step
# Época 90
# 645/645 - 1s - loss: 3.0931e-04 - 982ms/epoch - 2ms/step
# Época 91
# 645/645 - 1s - loss: 3.0448e-04 - 797ms/epoch - 1ms/step
# Época 92
# 645/645 - 1s - loss: 3.1820e-04 - 787ms/epoch - 1ms/step
# Época 93
# 645/645 - 1s - loss: 3.2559e-04 - 765ms/epoch - 1ms/step
# Época 94
# 645/645 - 1s - loss: 3.2422e-04 - 789ms/epoch - 1ms/step
# Época 95
# 645/645 - 1s - loss: 3.2607e-04 - 780ms/epoch - 1ms/step
# Época 96
# 645/645 - 1s - loss: 3.2166e-04 - 805ms/epoch - 1ms/step
# Época 97
# 645/645 - 1s - loss: 3.2936e-04 - 819ms/epoch - 1ms/step
# Época 98
# 645/645 - 1s - loss: 3.2736e-04 - 776ms/epoch - 1ms/step
# Época 99
# 645/645 - 1s - loss: 3.3417e-04 - 770ms/epoch - 1ms/step
# Época 100
# 645/645 - 1s - loss: 3.4181e-04 - 861ms/epoch - 1ms/step
# Época 101
# 645/645 - 1s - loss: 3.4534e-04 - 1s/epoch - 2ms/step
# Época 102
# 645/645 - 1s - loss: 3.4137e-04 - 804ms/epoch - 1ms/step
# Época 103
# 645/645 - 1s - loss: 3.4768e-04 - 786ms/epoch - 1ms/step
# Época 104
# 645/645 - 1s - loss: 3.6164e-04 - 769ms/epoch - 1ms/step
# Época 105
# 645/645 - 1s - loss: 3.5621e-04 - 797ms/epoch - 1ms/step
# Época 106
# 645/645 - 1s - loss: 3.6257e-04 - 764ms/epoch - 1ms/step
# Época 107
# 645/645 - 1s - loss: 3.5544e-04 - 777ms/epoch - 1ms/step
# Época 108
# 645/645 - 1s - loss: 3.6480e-04 - 785ms/epoch - 1ms/step
# Época 109
# 645/645 - 1s - loss: 3.5762e-04 - 772ms/epoch - 1ms/step
# Época 110
# 645/645 - 1s - loss: 3.6308e-04 - 763ms/epoch - 1ms/step
# Época 111
# 645/645 - 1s - loss: 3.5763e-04 - 795ms/epoch - 1ms/step
# Época 112
# 645/645 - 1s - loss: 3.6156e-04 - 992ms/epoch - 2ms/step
# Época 113
# 645/645 - 1s - loss: 3.4808e-04 - 920ms/epoch - 1ms/step
# Época 114
# 645/645 - 1s - loss: 3.3895e-04 - 774ms/epoch - 1ms/step
# Época 115
# 645/645 - 1s - loss: 3.3149e-04 - 806ms/epoch - 1ms/step
# Época 116
# 645/645 - 1s - loss: 3.2534e-04 - 768ms/epoch - 1ms/step
# Época 117
# 645/645 - 1s - loss: 3.2041e-04 - 763ms/epoch - 1ms/step
# Época 118
# 645/645 - 1s - loss: 3.1738e-04 - 802ms/epoch - 1ms/step
# Época 119
# 645/645 - 1s - loss: 3.1484e-04 - 761ms/epoch - 1ms/step
# Época 120
# 645/645 - 1s - loss: 3.1153e-04 - 770ms/epoch - 1ms/step
# Época 121
# 645/645 - 1s - loss: 3.0858e-04 - 757ms/epoch - 1ms/step
# Época 122
# 645/645 - 1s - loss: 3.0610e-04 - 839ms/epoch - 1ms/step
# Época 123
# 645/645 - 1s - loss: 3.0383e-04 - 786ms/epoch - 1ms/step
# Época 124
# 645/645 - 1s - loss: 3.0194e-04 - 944ms/epoch - 1ms/step
# Época 125
# 645/645 - 1s - loss: 3.0025e-04 - 947ms/epoch - 1ms/step
# Época 126
# 645/645 - 1s - loss: 2.9864e-04 - 755ms/epoch - 1ms/step
# Época 127
# 645/645 - 1s - loss: 2.9692e-04 - 743ms/epoch - 1ms/step
# Época 128
# 645/645 - 1s - loss: 2.9477e-04 - 768ms/epoch - 1ms/step
# Época 129
# 645/645 - 1s - loss: 2.9272e-04 - 775ms/epoch - 1ms/step
# Época 130
# 645/645 - 1s - loss: 2.9101e-04 - 759ms/epoch - 1ms/step
# Época 131
# 645/645 - 1s - loss: 2.8965e-04 - 776ms/epoch - 1ms/step
# Época 132
# 645/645 - 1s - loss: 2.8860e-04 - 861ms/epoch - 1ms/step
# Época 133
# 645/645 - 1s - loss: 2.8791e-04 - 791ms/epoch - 1ms/step
# Época 134
# 645/645 - 1s - loss: 2.8745e-04 - 1s/epoch - 2ms/step
# Época 135
# 645/645 - 1s - loss: 2.8693e-04 - 831ms/epoch - 1ms/step
# Época 136
# 645/645 - 1s - loss: 2.8606e-04 - 755ms/epoch - 1ms/step
# Época 137
# 645/645 - 1s - loss: 2.8490e-04 - 923ms/epoch - 1ms/step
# Época 138
# 645/645 - 1s - loss: 2.8403e-04 - 759ms/epoch - 1ms/step
# Época 139
# 645/645 - 1s - loss: 2.8356e-04 - 746ms/epoch - 1ms/step
# Época 140
# 645/645 - 1s - loss: 2.8306e-04 - 779ms/epoch - 1ms/step
# Época 141
# 645/645 - 1s - loss: 2.8105e-04 - 764ms/epoch - 1ms/step
# Época 142
# 645/645 - 1s - loss: 2.7915e-04 - 816ms/epoch - 1ms/step
# Época 143
# 645/645 - 1s - loss: 2.7848e-04 - 746ms/epoch - 1ms/step
# Época 144
# 645/645 - 1s - loss: 2.7862e-04 - 1s/epoch - 2ms/step
# Época 145
# 645/645 - 1s - loss: 2.7615e-04 - 865ms/epoch - 1ms/step
# Época 146
# 645/645 - 1s - loss: 2.7989e-04 - 762ms/epoch - 1ms/step
# Época 147
# 645/645 - 1s - loss: 2.7720e-04 - 790ms/epoch - 1ms/step
# Época 148
# 645/645 - 1s - loss: 2.7820e-04 - 773ms/epoch - 1ms/step
# Época 149
# 645/645 - 1s - loss: 2.7782e-04 - 785ms/epoch - 1ms/step
# Época 150
# 645/645 - 1s - loss: 2.7846e-04 - 781ms/epoch - 1ms/step
# Época 151
# 645/645 - 1s - loss: 2.7938e-04 - 785ms/epoch - 1ms/step
# Época 152
# 645/645 - 1s - loss: 2.8127e-04 - 770ms/epoch - 1ms/step
# Época 153
# 645/645 - 1s - loss: 2.8099e-04 - 764ms/epoch - 1ms/step
# Época 154
# 645/645 - 1s - loss: 2.8406e-04 - 904ms/epoch - 1ms/step
# Época 155
# 645/645 - 1s - loss: 2.8343e-04 - 962ms/epoch - 1ms/step
# Época 156
# 645/645 - 1s - loss: 2.8281e-04 - 760ms/epoch - 1ms/step
# Época 157
# 645/645 - 1s - loss: 2.8197e-04 - 780ms/epoch - 1ms/step
# Época 158
# 645/645 - 1s - loss: 2.8206e-04 - 764ms/epoch - 1ms/step
# Época 159
# 645/645 - 1s - loss: 2.7469e-04 - 773ms/epoch - 1ms/step
# Época 160
# 645/645 - 1s - loss: 2.6918e-04 - 774ms/epoch - 1ms/step
# Época 161
# 645/645 - 1s - loss: 2.6463e-04 - 774ms/epoch - 1ms/step
# Época 162
# 645/645 - 1s - loss: 2.6264e-04 - 745ms/epoch - 1ms/step
# Época 163
# 645/645 - 1s - loss: 2.6179e-04 - 778ms/epoch - 1ms/step
# Época 164
# 645/645 - 1s - loss: 2.5902e-04 - 775ms/epoch - 1ms/step
# Época 165
# 645/645 - 1s - loss: 2.6084e-04 - 1s/epoch - 2ms/step
# Época 166
# 645/645 - 1s - loss: 2.5560e-04 - 760ms/epoch - 1ms/step
# Época 167
# 645/645 - 1s - loss: 2.5486e-04 - 752ms/epoch - 1ms/step
# Época 168
# 645/645 - 1s - loss: 2.5261e-04 - 764ms/epoch - 1ms/step
# Época 169
# 645/645 - 1s - loss: 2.5258e-04 - 773ms/epoch - 1ms/step
# Época 170
# 645/645 - 1s - loss: 2.4877e-04 - 821ms/epoch - 1ms/step
# Época 171
# 645/645 - 1s - loss: 2.4869e-04 - 753ms/epoch - 1ms/step
# Época 172
# 645/645 - 1s - loss: 2.4772e-04 - 772ms/epoch - 1ms/step
# Época 173
# 645/645 - 1s - loss: 2.4897e-04 - 781ms/epoch - 1ms/step
# Época 174
# 645/645 - 1s - loss: 2.4588e-04 - 790ms/epoch - 1ms/step
# Época 175
# 645/645 - 1s - loss: 2.4796e-04 - 892ms/epoch - 1ms/step
# Época 176
# 645/645 - 1s - loss: 2.4482e-04 - 1s/epoch - 2ms/step
# Época 177
# 645/645 - 1s - loss: 2.4561e-04 - 762ms/epoch - 1ms/step
# Época 178
# 645/645 - 1s - loss: 2.4065e-04 - 772ms/epoch - 1ms/step
# Época 179
# 645/645 - 1s - loss: 2.4432e-04 - 773ms/epoch - 1ms/step
# Época 180
# 645/645 - 1s - loss: 2.3862e-04 - 769ms/epoch - 1ms/step
# Época 181
# 645/645 - 1s - loss: 2.4156e-04 - 762ms/epoch - 1ms/step
# Época 182
# 645/645 - 1s - loss: 2.4112e-04 - 778ms/epoch - 1ms/step
# Época 183
# 645/645 - 1s - loss: 2.4040e-04 - 757ms/epoch - 1ms/step
# Época 184
# 645/645 - 1s - loss: 2.3771e-04 - 803ms/epoch - 1ms/step
# Época 185
# 645/645 - 1s - loss: 2.3861e-04 - 786ms/epoch - 1ms/step
# Época 186
# 645/645 - 1s - loss: 2.3414e-04 - 789ms/epoch - 1ms/step
# Época 187
# 645/645 - 1s - loss: 2.3606e-04 - 903ms/epoch - 1ms/step
# Época 188
# 645/645 - 1s - loss: 2.3464e-04 - 834ms/epoch - 1ms/step
# Época 189
# 645/645 - 1s - loss: 2.3517e-04 - 761ms/epoch - 1ms/step
# Época 190
# 645/645 - 1s - loss: 2.3148e-04 - 775ms/epoch - 1ms/step
# Época 191
# 645/645 - 1s - loss: 2.3289e-04 - 762ms/epoch - 1ms/step
# Época 192
# 645/645 - 1s - loss: 2.3080e-04 - 804ms/epoch - 1ms/step
# Época 193
# 645/645 - 1s - loss: 2.3283e-04 - 766ms/epoch - 1ms/step
# Época 194
# 645/645 - 1s - loss: 2.3259e-04 - 762ms/epoch - 1ms/step
# Época 195
# 645/645 - 1s - loss: 2.3293e-04 - 778ms/epoch - 1ms/step
# Época 196
# 645/645 - 1s - loss: 2.3381e-04 - 870ms/epoch - 1ms/step
# Época 197
# 645/645 - 1s - loss: 2.3319e-04 - 889ms/epoch - 1ms/step
# Época 198
# 645/645 - 1s - loss: 2.3383e-04 - 748ms/epoch - 1ms/step
# Época 199
# 645/645 - 1s - loss: 2.3381e-04 - 792ms/epoch - 1ms/step
# Época 200
# 645/645 - 1s - loss: 2.3160e-04 - 794ms/epoch - 1ms/step
# Época 201
# 645/645 - 1s - loss: 2.3225e-04 - 765ms/epoch - 1ms/step
# Época 202
# 645/645 - 1s - loss: 2.3124e-04 - 761ms/epoch - 1ms/step
# Época 203
# 645/645 - 1s - loss: 2.3181e-04 - 842ms/epoch - 1ms/step
# Época 204
# 645/645 - 1s - loss: 2.3093e-04 - 861ms/epoch - 1ms/step
# Época 205
# 645/645 - 1s - loss: 2.3177e-04 - 783ms/epoch - 1ms/step
# Época 206
# 645/645 - 1s - loss: 2.3032e-04 - 885ms/epoch - 1ms/step
# Época 207
# 645/645 - 1s - loss: 2.3129e-04 - 1s/epoch - 2ms/step
# Época 208
# 645/645 - 1s - loss: 2.3016e-04 - 781ms/epoch - 1ms/step
# Época 209
# 645/645 - 1s - loss: 2.3121e-04 - 780ms/epoch - 1ms/step
# Época 210
# 645/645 - 1s - loss: 2.2983e-04 - 787ms/epoch - 1ms/step
# Época 211
# 645/645 - 1s - loss: 2.3084e-04 - 801ms/epoch - 1ms/step
# Época 212
# 645/645 - 1s - loss: 2.2933e-04 - 786ms/epoch - 1ms/step
# Época 213
# 645/645 - 1s - loss: 2.3026e-04 - 759ms/epoch - 1ms/step
# Época 214
# 645/645 - 1s - loss: 2.2854e-04 - 806ms/epoch - 1ms/step
# Época 215
# 645/645 - 1s - loss: 2.2965e-04 - 777ms/epoch - 1ms/step
# Época 216
# 645/645 - 1s - loss: 2.2810e-04 - 1s/epoch - 2ms/step
# Época 217
# 645/645 - 1s - loss: 2.2913e-04 - 783ms/epoch - 1ms/step
# Época 218
# 645/645 - 1s - loss: 2.2749e-04 - 775ms/epoch - 1ms/step
# Época 219
# 645/645 - 1s - loss: 2.2876e-04 - 791ms/epoch - 1ms/step
# Época 220
# 645/645 - 1s - loss: 2.2714e-04 - 777ms/epoch - 1ms/step
# Época 221
# 645/645 - 1s - loss: 2.2856e-04 - 766ms/epoch - 1ms/step
# Época 222
# 645/645 - 1s - loss: 2.2703e-04 - 795ms/epoch - 1ms/step
# Época 223
# 645/645 - 1s - loss: 2.2852e-04 - 794ms/epoch - 1ms/step
# Época 224
# 645/645 - 1s - loss: 2.2693e-04 - 772ms/epoch - 1ms/step
# Época 225
# 645/645 - 1s - loss: 2.2867e-04 - 789ms/epoch - 1ms/step
# Época 226
# 645/645 - 1s - loss: 2.2704e-04 - 885ms/epoch - 1ms/step
# Época 227
# 645/645 - 1s - loss: 2.2894e-04 - 1s/epoch - 2ms/step
# Época 228
# 645/645 - 1s - loss: 2.2711e-04 - 802ms/epoch - 1ms/step
# Época 229
# 645/645 - 1s - loss: 2.2929e-04 - 757ms/epoch - 1ms/step
# Época 230
# 645/645 - 1s - loss: 2.2716e-04 - 790ms/epoch - 1ms/step
# Época 231
# 645/645 - 1s - loss: 2.2958e-04 - 775ms/epoch - 1ms/step
# Época 232
# 645/645 - 1s - loss: 2.2719e-04 - 756ms/epoch - 1ms/step
# Época 233
# 645/645 - 1s - loss: 2.2972e-04 - 780ms/epoch - 1ms/step
# Época 234
# 645/645 - 1s - loss: 2.2706e-04 - 798ms/epoch - 1ms/step
# Época 235
# 645/645 - 1s - loss: 2.2971e-04 - 763ms/epoch - 1ms/step
# Época 236
# 645/645 - 1s - loss: 2.2699e-04 - 761ms/epoch - 1ms/step
# Época 237
# 645/645 - 1s - loss: 2.2954e-04 - 965ms/epoch - 1ms/step
# Época 238
# 645/645 - 1s - loss: 2.2683e-04 - 807ms/epoch - 1ms/step
# Época 239
# 645/645 - 1s - loss: 2.2934e-04 - 752ms/epoch - 1ms/step
# Época 240
# 645/645 - 1s - loss: 2.2668e-04 - 804ms/epoch - 1ms/step
# Época 241
# 645/645 - 1s - loss: 2.2912e-04 - 759ms/epoch - 1ms/step
# Época 242
# 645/645 - 1s - loss: 2.2654e-04 - 773ms/epoch - 1ms/step
# Época 243
# 645/645 - 1s - loss: 2.2878e-04 - 769ms/epoch - 1ms/step
# Época 244
# 645/645 - 1s - loss: 2.2633e-04 - 788ms/epoch - 1ms/step
# Época 245
# 645/645 - 1s - loss: 2.2846e-04 - 776ms/epoch - 1ms/step
# Época 246
# 645/645 - 1s - loss: 2.2624e-04 - 859ms/epoch - 1ms/step
# Época 247
# 645/645 - 1s - loss: 2.2816e-04 - 802ms/epoch - 1ms/step
# Época 248
# 645/645 - 1s - loss: 2.2618e-04 - 780ms/epoch - 1ms/step
# Época 249
# 645/645 - 1s - loss: 2.2790e-04 - 768ms/epoch - 1ms/step
# Época 250
# 645/645 - 1s - loss: 2.2617e-04 - 762ms/epoch - 1ms/step
# Época 251
# 645/645 - 1s - loss: 2.2755e-04 - 777ms/epoch - 1ms/step
# Época 252
# 645/645 - 1s - loss: 2.2632e-04 - 753ms/epoch - 1ms/step
# Época 253
# 645/645 - 1s - loss: 2.2715e-04 - 772ms/epoch - 1ms/step
# Época 254
# 645/645 - 1s - loss: 2.2652e-04 - 764ms/epoch - 1ms/step
# Época 255
# 645/645 - 1s - loss: 2.2669e-04 - 780ms/epoch - 1ms/step
# Época 256
# 645/645 - 1s - loss: 2.2656e-04 - 891ms/epoch - 1ms/step
# Época 257
# 645/645 - 1s - loss: 2.2629e-04 - 938ms/epoch - 1ms/step
# Época 258
# 645/645 - 1s - loss: 2.2629e-04 - 769ms/epoch - 1ms/step
# Época 259
# 645/645 - 1s - loss: 2.2607e-04 - 750ms/epoch - 1ms/step
# Época 260
# 645/645 - 1s - loss: 2.2591e-04 - 764ms/epoch - 1ms/step
# Época 261
# 645/645 - 1s - loss: 2.2579e-04 - 774ms/epoch - 1ms/step
# Época 262
# 645/645 - 1s - loss: 2.2557e-04 - 767ms/epoch - 1ms/step
# Época 263
# 645/645 - 1s - loss: 2.2542e-04 - 801ms/epoch - 1ms/step
# Época 264
# 645/645 - 1s - loss: 2.2525e-04 - 790ms/epoch - 1ms/step
# Época 265
# 645/645 - 1s - loss: 2.2536e-04 - 808ms/epoch - 1ms/step
# Época 266
# 645/645 - 1s - loss: 2.2547e-04 - 938ms/epoch - 1ms/step
# Época 267
# 645/645 - 1s - loss: 2.2440e-04 - 834ms/epoch - 1ms/step
# Época 268
# 645/645 - 1s - loss: 2.2410e-04 - 790ms/epoch - 1ms/step
# Época 269
# 645/645 - 1s - loss: 2.2398e-04 - 791ms/epoch - 1ms/step
# Época 270
# 645/645 - 1s - loss: 2.2387e-04 - 769ms/epoch - 1ms/step
# Época 271
# 645/645 - 1s - loss: 2.2380e-04 - 775ms/epoch - 1ms/step
# Época 272
# 645/645 - 1s - loss: 2.2368e-04 - 770ms/epoch - 1ms/step
# Época 273
# 645/645 - 1s - loss: 2.2358e-04 - 799ms/epoch - 1ms/step
# Época 274
# 645/645 - 1s - loss: 2.2348e-04 - 776ms/epoch - 1ms/step
# Época 275
# 645/645 - 1s - loss: 2.2340e-04 - 770ms/epoch - 1ms/step
# Época 276
# 645/645 - 1s - loss: 2.2333e-04 - 816ms/epoch - 1ms/step
# Época 277
# 645/645 - 1s - loss: 2.2324e-04 - 932ms/epoch - 1ms/step
# Época 278
# 645/645 - 1s - loss: 2.2316e-04 - 823ms/epoch - 1ms/step
# Época 279
# 645/645 - 1s - loss: 2.2309e-04 - 781ms/epoch - 1ms/step
# Época 280
# 645/645 - 1s - loss: 2.2300e-04 - 790ms/epoch - 1ms/step
# Época 281
# 645/645 - 1s - loss: 2.2286e-04 - 749ms/epoch - 1ms/step
# Época 282
# 645/645 - 1s - loss: 2.2270e-04 - 793ms/epoch - 1ms/step
# Época 283
# 645/645 - 1s - loss: 2.2254e-04 - 756ms/epoch - 1ms/step
# Época 284
# 645/645 - 1s - loss: 2.2240e-04 - 754ms/epoch - 1ms/step
# Época 285
# 645/645 - 1s - loss: 2.2230e-04 - 768ms/epoch - 1ms/step
# Época 286
# 645/645 - 1s - loss: 2.2225e-04 - 892ms/epoch - 1ms/step
# Época 287
# 645/645 - 1s - loss: 2.2223e-04 - 1s/epoch - 2ms/step
# Época 288
# 645/645 - 1s - loss: 2.2224e-04 - 771ms/epoch - 1ms/step
# Época 289
# 645/645 - 1s - loss: 2.2225e-04 - 759ms/epoch - 1ms/step
# Época 290
# 645/645 - 1s - loss: 2.2226e-04 - 770ms/epoch - 1ms/step
# Época 291
# 645/645 - 1s - loss: 2.2225e-04 - 773ms/epoch - 1ms/step
# Época 292
# 645/645 - 1s - loss: 2.2222e-04 - 775ms/epoch - 1ms/step
# Época 293
# 645/645 - 1s - loss: 2.2217e-04 - 747ms/epoch - 1ms/step
# Época 294
# 645/645 - 1s - loss: 2.2214e-04 - 759ms/epoch - 1ms/step
# Época 295
# 645/645 - 1s - loss: 2.2215e-04 - 779ms/epoch - 1ms/step
# Época 296
# 645/645 - 1s - loss: 2.2222e-04 - 762ms/epoch - 1ms/step
# Época 297
# 645/645 - 1s - loss: 2.2237e-04 - 735ms/epoch - 1ms/step
# Época 298
# 645/645 - 1s - loss: 2.2256e-04 - 892ms/epoch - 1ms/step
# Época 299
# 645/645 - 1s - loss: 2.2275e-04 - 766ms/epoch - 1ms/step
# 645/645 [==============================] - 1s 982us/step
# 317/317 [==============================] - 0s 1ms/step
# Train Score: 4.03 RMSE
# Test Score: 12.83 RMSE

# %% [markdown]
# En este caso, además de tardar más tiempo al tener más épocas. Además, train score y test score también han disminuído. Aunque son mayores que los del experimento de mayor número de neuronas.

# %% [markdown]
# ## Referencias
#
# Este material se ha basado en la entrada ["Time Series Prediction with LSTM Recurrent Neural Networks in Python with Keras"](https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/) de Machine Learning Mastery. Es muy recomendable consultar la entrada completa.
